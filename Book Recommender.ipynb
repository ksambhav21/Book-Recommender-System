# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
books = pd.read_csv('books datasets/books.csv')
users = pd.read_csv('books datasets/users.csv')
ratings = pd.read_csv('books datasets/ratings.csv')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %% [markdown]
# ## Popularity Based Recommender

# %%
books_ratings=ratings.merge(books,on='ISBN')

# %%
books_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
votes_df = books_ratings.groupby(by='Book-Title').count()['Book-Rating']

# %%
votes_df = votes_df.reset_index(name='num_votes')

# %%
votes_df = votes_df[votes_df['num_votes']>400]

# %%
votes_df
# Out:
#                                                Book-Title  num_votes
# 818                                   1st to Die: A Novel        509
# 5303                                      A Painted House        838
# 5664                              A Prayer for Owen Meany        413
# 6980                                       A Time to Kill        549
# 14392                                 Angels &amp; Demons        670
# ...                                                   ...        ...
# 219741                              To Kill a Mockingbird        510
# 223135  Tuesdays with Morrie: An Old Man, a Young Man,...        493
# 233370  Where the Heart Is (Oprah's Book Club (Paperba...        585
# 233513                                   While I Was Gone        431
# 234951                                        Wild Animus       2502
#
# [64 rows x 2 columns]

# %%
avg_rating_df = books_ratings.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = votes_df.merge(avg_rating_df,on='Book-Title')
popular_df=popular_df.sort_values(by='avg_rating',ascending=False).head(50)

# %%
popular_df.reset_index(drop=True,inplace=True)

# %%
popular_df.head(10)
# Out:
#                                           Book-Title  num_votes  avg_rating
# 0  Harry Potter and the Prisoner of Azkaban (Book 3)        428    5.852804
# 1   Harry Potter and the Chamber of Secrets (Book 2)        556    5.183453
# 2  Harry Potter and the Sorcerer's Stone (Harry P...        575    4.895652
# 3                              To Kill a Mockingbird        510    4.700000
# 4                                  The Da Vinci Code        898    4.642539
# 5                 The Five People You Meet in Heaven        430    4.551163
# 6                             The Catcher in the Rye        449    4.545657
# 7                          The Lovely Bones: A Novel       1295    4.468726
# 8                            The Secret Life of Bees        774    4.447028
# 9  Tuesdays with Morrie: An Old Man, a Young Man,...        493    4.354970

# %%
popular_df.iloc[9]['Book-Title']
# Out:
# "Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson"

# %% [markdown]
# ## Collaborative Filtering Based Recommendation System
# ##   Item based Collaborative Filtering

# %%
x = books_ratings.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = books_ratings[books_ratings['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
 pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data
